# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate review text for rr, so as a first step, let's extract the text from its review.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('../pickle/corpus.pkl')
data
# Out:
#                                                 review           full_name
# ktc  Amazing and beautiful place to stay : We went ...     KTDC Tea County
# mm   Okayish : Hotel is just fine but view is great...      Misty Mountain
# mtc  Well maintained with clean room, with great vi...  Munnar Tea Country
# rr   Rivelute, Munnar : Location was extremely good...      Rivulet Resort
# sc   Excellent Stay : Awesome experience in Swiss C...        Swiss County
# tv   Excellent service and staff : The location is ...          Tea Valley

# %%
# Extract only rr's text
rr_text = data.review.loc['rr']
rr_text[:200]
# Out:
# 'Rivelute, Munnar : Location was extremely good. Variety and good quality of food. All staff was polite, cooperative and always ready. Excellent Stay : All things are perfect like food stay and service'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for rr review, take a look at it
rr_dict = markov_chain(rr_text)
rr_dict
# Out:
# {'Rivelute,': ['Munnar'],
#  'Munnar': [':',
#   ':',
#   ':',
#   'and',
#   ':',
#   'Excellent',
#   'Its',
#   ':',
#   ':',
#   'town',
#   ':',
#   ':',
#   'City',
#   'and',
#   ':',
#   'but',
#   'it',
#   'town',
#   'is',
#   'is',
#   'town',
#   'town',
#   'with',
#   'valley,',
#   'city)',
#   'is',
#   'but',
#   'town.',
#   'town.',
#   'means',
#   'city,',
#   'and',
#   'but'],
#  ':': ['Location',
#   'All',
#   'The',
#   'Location',
#   'We',
#   'Best',
#   'Rivulet',
#   'It',
#   'Amazing',
#   'I',
#   'A',
#   'Nice',
#   'Amazing',
#   'Most',
#   'This',
#   'Nice',
#   'Food',
#   "It's",
#   'Pleasant',
#   "It's",
#   'It',
#   'Overall',
#   'It',
#   'We',
#   'Everything',
#   'The',
#   'Perfect',
#   'Enjoyed',
#   'Heavenly',
#   'Excellent',
#   'Excellent',
#   'Calm,',
#   'Good',
#   'Nice',
#   'It',
#   'Great',
#   'Good',
#   'The',
#   'Without',
#   'Highly',
#   'The',
#   'View',
#   'Very',
#   'The',
#   "Don't",
#   'Hotel',
#   'Location',
#   'Rivulet',
#   'Road',
#   'Overall',
#   'We',
#   'Eco',
#   'Nice',
#   'Would',
#   'Lack',
#   'Restaurant',
#   'Location',
#   'Amazing',
#   'Just',
#   'Excellent',
#   'The',
#   'Really',
#   'Only',
#   'Great',
#   'It',
#   'Excellent',
#   'Hotel',
#   'Great',
#   'Location,',
#   'The',
#   'Everything',
#   'Resort',
#   'We',
#   'Far',
#   'They',
#   'Amazing',
#   'The',
#   'River',
#   'Wrong',
#   'The',
#   'It',
#   'Good',
#   'Unbeatable',
#   'Nice',
#   "Didn't",
#   'THis',
#   'Spacious,',
#   'Experience',
#   'Fantastic',
#   'Nice',
#   'Overall',
#   'Good',
#   'The',
#   'Good',
#   'The',
#   'The',
#   'Good',
#   'We',
#   'The',
#   'The',
#   'Okay',
#   'Please',
#   'Honeymoon',
#   'We',
#   'This',
#   'Room',
#   'Reception',
#   'One',
#   'The',
#   'Excellent',
#   'Hotel',
#   'Overall',
#   'It',
#   'food',
#   'Situated',
#   'Our',
#   'THE',
#   'Best',
#   'Courteous',
#   'Rivulet',
#   'Really',
#   'Excellent',
#   'Needs',
#   'Exceptional',
#   'Located',
#   'A',
#   'The',
#   'The',
#   'Mr.',
#   'Rated',
#   'Food',
#   'Not',
#   'The',
#   'All',
#   'The',
#   'Stayed',
#   'I',
#   'It',
#   'Great',
#   'Had',
#   'Food',
#   'Well,',
#   'Location',
#   'The',
#   'Excellent',
#   'Very',
#   'Too',
#   'Wonderful',
#   'One',
#   'River',
#   'Very',
#   'Located',
#   'This',
#   'The',
#   'Excellent',
#   'Breakfast',
#   'Overall',
#   'Good',
#   'Really',
#   'Overall',
#   'This',
#   '1.',
#   'Waking',
#   'Food',
#   'Very',
#   'Superb',
#   'Good',
#   'Resort',
#   'It',
#   'Enjoyable',
#   'Good',
#   'Was',
#   'Awwsome',
#   'Our',
#   'The'],
#  'Location': ['was',
#   'and',
#   ':',
#   'and',
#   'is',
#   'is',
#   'is',
#   'is',
#   'has',
#   'a',
#   'was',
#   'was',
#   'of',
#   'and',
#   'is'],
#  'was': ['extremely',
#   'polite,',
#   'very',
#   'a',
#   'a',
#   'good.',
#   'nice.',
#   'bad,',
#   'very',
#   'little',
#   'not',
#   'something',
#   'average',
#   'very',
#   'great.',
#   'very',
#   'good',
#   'delicious',
#   'good.',
#   'wonderful.',
#   'very',
#   'wonderful',
#   'so',
#   'great.',
#   'very',
#   'amazing,',
#   'adequate.',
#   'excellent.',
#   'courteous',
#   'nice',
#   'just',
#   'good',
#   'above',
#   'good.',
#   'good',
#   'amazing.',
#   'good',
#   'good.',
#   'fine',
#   'nice.',
#   'just',
#   'perfect.',
#   'awesome.',
#   'efficient',
#   'good',
#   'very',
#   'great.',
#   'soothing.',
#   'OK.',
#   'the',
#   'really',
#   'the',
#   'awesome.',
#   'good',
#   'good',
#   'good',
#   'very',
#   'also',
#   'courteous',
#   'provided',
#   'really',
#   'a',
#   'quite',
#   'not',
#   'decent',
#   'a',
#   'plugged,',
#   'food',
#   'good',
#   'nice',
#   'not',
#   'just',
#   'good.',
#   'well',
#   'very',
#   'good',
#   'little',
#   'not',
#   'good',
#   'poor.',
#   'great',
#   'amazing.',
#   'nice,',
#   'amazing',
#   'the',
#   'not',
#   'busy',
#   'slow,',
#   'booked',
#   'the',
#   'pleasant',
#   'spacious',
#   'good,',
#   'on',
#   'good.',
#   'really',
#   'really',
#   'a',
#   'good',
#   'co-operative',
#   'a',
#   'the',
#   'a',
#   'very',
#   'good.',
#   'nice',
#   'average.',
#   'good',
#   'very',
#   'wonderful.',
#   'very',
#   'beautiful.',
#   'even',
#   'luxurious',
#   'very',
#   'really',
#   'the',
#   'exactly',
#   'amazingly',
#   'the',
#   'food',
#   'nice',
#   'very',
#   'a',
#   'very',
#   'okay.',
#   'bad',
#   'unsafe',
#   'so',
#   'limited',
#   'broken,',
#   'food',
#   'good',
#   'about',
#   'not',
#   'quite',
#   'not',
#   'fine.',
#   'good',
#   'supporting',
#   'good',
#   'awesome',
#   'very',
#   'beautiful,',
#   'tasty,',
#   'very',
#   'awesome.',
#   'well',
#   'good.',
#   'with',
#   'not',
#   'surrounded',
#   'great.',
#   'average',
#   'good.',
#   'good.',
#   'perfect',
#   'perfect.',
#   'perfect.',
#   'better.',
#   'quite',
#   'fantastic',
#   'fantastic',
#   'awesome',
#   'available.',
#   'I',
#   'good.',
#   'alright.',
#   'exceptional',
#   'alright.',
#   'good.',
#   'beautiful.',
#   'even',
#   'luxurious',
#   'good.',
#   'quite',
#   'an',
#   'unforgettable.',
#   'very',
#   'attractive',
#   'very',
#   'very',
#   'very',
#   'good',
#   'such',
#   'superb',
#   'also',
#   'not',
#   'excellent.',
#   'far',
#   'a'],
#  'extremely': ['good.', 'well-trained', 'helpful'],
#  'good.': ['Variety',
#   'The',
#   'Excellent',
#   'The',
#   'Service',
#   'I',
#   'Foof',
#   'Staffs',
#   'Breakfast',
#   'Excellent',
#   'We',
#   'An',
#   'Kids',
#   'On',
#   'Resort',
#   'Should',
#   'Staff',
#   'Overall',
#   'Average',
#   'Though',
#   'Clean.',
#   'The',
#   'Good',
#   'I',
#   'View',
#   'Only',
#   'Good',
#   'Staff',
#   'Everything',
#   'We',
#   'Food',
#   'Awesome',
#   'Staff',
#   'Overall',
#   'Excellent',
#   'Very',
#   'Staff',
#   'All',
#   'If',
#   'Chicken',
#   'Breakfast'],
#  'Variety': ['and', 'in', 'of'],
#  'and': ['good',
#   'always',
#   'service.',
#   'probably',
#   'still',
#   'it',
#   'made',
#   'a',
#   'staff',
#   'serene',
#   'Munnar',
#   'the',
#   'also',
#   'very',
#   'the',
#   'calm',
#   'mountain',
#   'service',
#   'clean.',
#   'had',
#   'my',
#   'dinner',
#   'at',
#   'u',
#   'set',
#   'courteous.',
#   'hope',
#   'adventure',
#   'luxury',
#   'polite.',
#   'location',
#   'we',
#   'serene',
#   'service.',
#   'swimming',
#   'facilities',
#   'feel',
#   'views.',
#   'wonderful',
#   'satisfactory.',
#   'clean.',
#   'the',
#   'good',
#   'busy',
#   'location',
#   'ambience',
#   'service',
#   'shown',
#   'room',
#   'excellent',
#   'cottage',
#   'offer',
#   'enjoyed',
#   'total',
#   'helpful',
#   'scenic',
#   'friendly',
#   'clean',
#   'peaceful',
#   'well',
#   'major',
#   'staff.',
#   'they',
#   'breakfast',
#   'breakfast',
#   'clean.',
#   'staff',
#   'superb',
#   'enjoyed',
#   'rooms',
#   'relaxed',
#   'we',
#   'helpful.',
#   'we',
#   'encouraging',
#   'we',
#   'service',
#   'bathroom',
#   'the',
#   'helpful.',
#   '3',
#   'misty',
#   'always',
#   'their',
#   'climate',
#   'food',
#   'very',
#   'cuckoo',
#   'every',
#   'the',
#   'courteous.',
#   'you',
#   'a',
#   'good',
#   'good',
#   'friends.',
#   'facilities',
#   'archery',
#   'relaxing.',
#   'archery',
#   'seems',
#   'services',
#   'co-operative',
#   'beauty.',
#   'dam',
#   'his',
#   'quite',
#   'given',
#   'great',
#   'experienced',
#   'location.',
#   'friendly',
#   'good',
#   'dam',
#   'service',
#   'relaxed',
#   'also',
#   'clean.',
#   'the',
#   'the',
#   'the',
#   'away',
#   'good',
#   'garden.',
#   'two',
#   'we',
#   'the',
#   'not',
#   'spacious.',
#   'the',
#   'spacious',
#   'without',
#   'we',
#   'clean.',
#   'a',
#   'the',
#   'location',
#   'all',
#   'enjoying',
#   'amenities',
#   'slides.',
#   'all',
#   'online',
#   'decided',
#   'tea',
#   'clean',
#   'the',
#   'all',
#   'even',
#   'neatly',
#   'I',
#   'enjoying',
#   'amenities',
#   'right',
#   'good...',
#   'a',
#   'beautiful.',
#   'neat.',
#   'the',
#   'have',
#   'overlooking',
#   'beautiful',
#   'dining',
#   'a',
#   'a',
#   'a',
#   'co-operative',
#   'made',
#   'if',
#   'the',
#   'courteous.',
#   'comfortable.',
#   'exotic',
#   'plush',
#   'personalised',
#   'mountain.',
#   'staff',
#   'is',
#   'cocoa',
#   'huge.',
#   'too',
#   'enjoyed',
#   'so',
#   'bathroom,',
#   'maintained',
#   'clean.',
#   'equipped',
#   'cordial.',
#   'quiet',
#   'staff',
#   'will',
#   'family.',
#   'greet',
#   'food',
#   'breathtaking',
#   'span',
#   'the',
#   'probably',
#   'presentation',
#   'welcoming',
#   'they',
#   'again',
#   'polite',
#   'spices',
#   'helpful.',
#   'entertaining',
#   'by',
#   'clean,',
#   'I',
#   'my',
#   'motion',
#   'hospitable.',
#   'clean.',
#   'bad',
#   'a',
#   'I',
#   'no',
#   'out',
#   'services',
#   'January',
#   'tasty',
#   'premier',
#   'always',
#   'room',
#   'provided',
#   'staff',
#   'trees',
#   'nature',
#   'clean.',
#   'everything',
#   'cocoa',
#   'marvelous.',
#   'location',
#   'would',
#   'design',
#   'awesome.',
#   'very',
#   'family.',
#   'hospitality.',
#   'day',
#   'warmth,',
#   'scenic',
#   'it',
#   'integral',
#   'clean,',
#   'take',
#   'do',
#   'the',
#   'ambience',
#   'clean',
#   'are',
#   'asked',
#   'then',
#   'want',
#   'made',
#   'the',
#   'is',
#   'cocoa',
#   'huge.',
#   'too',
#   'awesome',
#   'Pool',
#   'I',
#   'the',
#   'seek',
#   'the',
#   'their',
#   'think',
#   'other',
#   'soup',
#   'all',
#   'stay',
#   'property..had',
#   'its',
#   'food',
#   'staff',
#   'if',
#   'made',
#   'dangerous,'],
#  'good': ['quality',
#   'view',
#   'but',
#   'food,',
#   'taste',
#   'place',
#   'service',
#   'property',
#   'and',
#   'at',
#   'Good',
#   'experience',
#   'budget',
#   'view',
#   'service',
#   'too.',
#   'but',
#   'experience.',
#   'cottage',
#   'and',
#   'shots.',
#   'food',
#   ':',
#   'on',
#   'but',
#   'to',
#   'and',
#   'staff,',
#   'rooms.',
#   'and',
#   'time',
#   'stay',
#   'but',
#   'location.',
#   'for',
#   'and',
#   'location.',
#   'though',
#   'place',
#   ':',
#   'and',
#   'and',
#   'ambience.',
#   'option',
#   'landscape',
#   'staff.',
#   'but',
#   'at',
#   'at',
#   'for',
#   'taste',
#   'spread.',
#   'view.',
#   'for',
#   'tree',
#   'but',
#   'food',
#   'to',
#   'stay,',
#   'staff',
#   'food',
#   'stay.',
#   ':',
#   'staff',
#   'staff',
#   "children's",
#   'but',
#   'and',
#   'option.',
#   'thing',
#   'location',
#   'for',
#   'except',
#   'and',
#   'and',
#   'services.',
#   'and',
#   'with',
#   'resort.',
#   'resort.',
#   'and',
#   'response',
#   'food.',
#   'place',
#   'location',
#   'location',
#   'and',
#   'food.',
#   'stay.',
#   'value',
#   'maintenance',
#   'resort',
#   'of',
#   'very',
#   'hospitality.',
#   'at',
#   'at',
#   'its',
#   'experience.'],
#  'quality': ['of',
#   'time',
#   'time',
#   'is',
#   'Resort.',
#   'requires',
#   'is',
#   'was',
#   'was',
#   'was',
#   'is',
#   'of',
#   'and',
#   'is',
#   'was',
#   'is',
#   'was'],
#  'of': ['food.',
#   'the',
#   'the',
#   'the',
#   'River.',
#   'a',
#   'holiday',
#   'new',
#   'couple',
#   'days',
#   'nature',
#   'friends.',
#   'food.',
#   'cottage',
#   'the',
#   'nights',
#   'potholes',
#   'service',
#   'the',
#   'water.',
#   'the',
#   'KSEB.',
#   'the',
#   'Mr.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this',
#   'the',
#   'a',
#   'the',
#   'green.',
#   'space',
#   'kindness',
#   'bad',
#   'average',
#   'the',
#   'the',
#   'the',
#   'a',
#   'resort',
#   'the',
#   'varieties!',
#   'the',
#   'tea.',
#   'the',
#   'the',
#   'security',
#   'his',
#   'hill',
#   'indoor',
#   'the',
#   'the',
#   'nature.',
#   'munnar',
#   'green',
#   'swimming',
#   'towels',
#   'the',
#   'all',
#   'a',
#   'breakfast.',
#   'cleaning/work.',
#   'the',
#   'Rivulet',
#   'the',
#   'course.',
#   'the',
#   'insects',
#   '24,',
#   'such',
#   'Munnar,',
#   'this',
#   'the',
#   'cottages',
#   'the',
#   'the',
#   'food',
#   'food',
#   'different',
#   'the',
#   'varieties',
#   'the',
#   'city',
#   'the'],
#  'food.': ['All', 'Enjoyed', 'Add', 'Best', 'I', 'Chef'],
#  'All': ['staff', 'things', 'was', 'was'],
#  'staff': ['was',
#   'were',
#   'of',
#   'was',
#   'is',
#   'is',
#   'behaviour',
#   'are',
#   'is',
#   'are',
#   'and',
#   'is',
#   'were',
#   'was',
#   'is',
#   'for',
#   ':',
#   'and',
#   ':',
#   'was',
#   'were',
#   'good',
#   'was',
#   ':',
#   'was',
#   'is',
#   'are',
#   'was',
#   'needs',
#   'of',
#   'we',
#   'were',
#   'were',
#   '-',
#   'were',
#   'behavior',
#   'were'],
#  'polite,': ['cooperative'],
#  'cooperative': ['and'],
#  'always': ['ready.',
#   'ready',
#   'recommend',
#   'smiling.',
#   'ready',
#   'giving',
#   'take'],
#  'ready.': ['Excellent'],
#  'Excellent': ['Stay',
#   'Stay',
#   'place,',
#   'Stay',
#   'view',
#   'Stay',
#   'Resort.',
#   'Resort',
#   'resort',
#   'location,',
#   'Stay',
#   'hospitality',
#   'Stay',
#   ':',
#   ':',
#   'stay,',
#   'stay',
#   'location,',
#   'location',
#   'hotel',
#   'location,',
#   'place',
#   'place',
#   'Stay',
#   'Stay',
#   'location',
#   'Stay',
#   'place',
#   'Stay',
#   'Stay',
#   ':',
#   'hotel',
#   'Stay',
#   'and',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay'],
#  'Stay': [':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   'at',
#   ':',
#   ':',
#   ':',
#   'at',
#   ':',
#   '!!!',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':'],
#  'things': ['are', 'were'],
#  'are': ['perfect',
#   'other',
#   'awesome.',
#   'here',
#   'specious',
#   'always',
#   'very',
#   'good',
#   'coming',
#   'best.',
#   'big',
#   'good.',
#   'little',
#   'really',
#   'awesome.',
#   'less.',
#   'amazing,',
#   'clean',
#   'much',
#   'so',
#   'provided',
#   'polite',
#   'very',
#   'booking',
#   'OK,',
#   'worth',
#   'spacious',
#   'quite',
#   'paying',
#   'many',
#   'quite',
#   'clean.',
#   'nice',
#   'too',
#   'very',
#   'required',
#   'clean',
#   'on',
#   'spacious',
#   'on',
#   'well',
#   'new',
#   'helpful',
#   'not',
#   'not',
#   'always',
#   'everywhere',
#   'big',
#   '24',
#   'happy',
#   'spacious,',
#   'worth',
#   'perfect.',
#   'nice',
#   'on',
#   'so',
#   'very',
#   'very'],
#  'perfect': ['like', 'and', 'stay!', 'ambience'],
#  'like': ['food',
#   'the',
#   'is',
#   'spice',
#   'location',
#   'Misty',
#   'they',
#   'location',
#   'home.',
#   'to',
#   'what',
#   'to',
#   'to',
#   'bamboo',
#   'to',
#   'to',
#   'the',
#   'to',
#   'to'],
#  'food': ['stay',
#   "wasn't",
#   'and',
#   'quality',
#   'will',
#   'there',
#   'was',
#   'was',
#   'and',
#   'but',
#   'properly,',
#   'quality',
#   'can',
#   ':',
#   'would',
#   'quality.',
#   'is',
#   'is',
#   'and',
#   '&',
#   ':',
#   'was',
#   'spread',
#   'menu',
#   ':',
#   '.',
#   'but',
#   'quality,',
#   'quality',
#   'options',
#   'anymore.',
#   'spread',
#   'served',
#   'available',
#   'was',
#   'was',
#   'is',
#   'not',
#   'menu',
#   'all'],
#  'stay': ['and',
#   'there',
#   'in',
#   'at',
#   'in',
#   'here',
#   'in',
#   'with',
#   ':',
#   ':',
#   'with',
#   'in',
#   'of',
#   'Superb',
#   ':',
#   'and',
#   'here.',
#   'in',
#   ':',
#   'was',
#   'view',
#   ':',
#   'and',
#   'in',
#   ':',
#   'was',
#   'there.',
#   'was',
#   ':',
#   'in',
#   'April',
#   'which',
#   'was',
#   'with',
#   ':',
#   'hungry',
#   ':',
#   'was',
#   '..',
#   ':',
#   'for',
#   'for',
#   'was',
#   'here.',
#   'more',
#   'and',
#   'there.',
#   'there.',
#   'and',
#   'at',
#   'in,',
#   'enjoyable.',
#   'till',
#   'here',
#   'delightful.',
#   'in',
#   'for',
#   'food'],
#  'service.': ['Loved', 'Nice', 'Cycling', 'Superb', 'There', ':'],
#  'Loved': ['it!', 'the', 'overall.', 'the', 'the', 'the'],
#  'it!': [':'],
#  'The': ['Resort',
#   'Resort',
#   'staff',
#   'tour',
#   'Resort',
#   'rooms',
#   'river',
#   'food',
#   'spread',
#   'location',
#   'staff',
#   'view',
#   'staff',
#   'location.',
#   'location',
#   'manager',
#   'jeep',
#   'staff',
#   'rooms',
#   'Resort',
#   'service',
#   'only',
#   'rooms',
#   'location',
#   'birds',
#   'food',
#   'stay',
#   'room',
#   'continuous',
#   'breakfast',
#   'only',
#   'Rivulet.',
#   'rooms',
#   'staff',
#   'pictures',
#   'only',
#   'staff',
#   'location',
#   'hotel',
#   'location',
#   'other',
#   'rooms',
#   'climate',
#   'pics',
#   'orchards',
#   'food',
#   'welcome',
#   'best',
#   'river',
#   'room,',
#   'morning',
#   'background',
#   'garden',
#   'price',
#   'spa',
#   'rooms',
#   'usual',
#   'location',
#   'service',
#   'view',
#   'Fog..',
#   'only',
#   'room',
#   'overall',
#   'place',
#   'rooms',
#   'balcony',
#   'resort',
#   'house',
#   'location,',
#   'staff',
#   'rooms',
#   'resort',
#   'rooms',
#   'food',
#   'suit',
#   'staff',
#   'resort',
#   'rooms',
#   'dinning',
#   'most',
#   'garden,',
#   'other',
#   'taxi',
#   'only',
#   'problem',
#   'worst',
#   'hospitality',
#   'food',
#   'hotel',
#   'view',
#   'best',
#   'staff',
#   'resort',
#   'cottages',
#   'food',
#   'stay',
#   'resort',
#   'property',
#   'owner',
#   'view',
#   'resort',
#   'rooms',
#   'food',
#   'maintenance',
#   'scenic',
#   'room',
#   'route'],
#  'Resort': ['is',
#   'has',
#   'at',
#   'is',
#   'and',
#   'provide',
#   ':',
#   ':',
#   'to',
#   'is',
#   'to',
#   'location',
#   ':',
#   'is',
#   'which',
#   'is',
#   'location',
#   'was',
#   'is',
#   'is',
#   'was',
#   'is',
#   'location',
#   'is',
#   'is',
#   'is'],
#  'is': ['located',
#   'during',
#   'a',
#   'main',
#   'a',
#   'incomplete',
#   'good.',
#   'spacious',
#   'about',
#   'best',
#   'too',
#   'terrible.',
#   'the',
#   'the',
#   'tasty',
#   'bearable.',
#   'extremely',
#   'what',
#   'amazing.',
#   'very',
#   'optimal',
#   'definitely',
#   'very',
#   'very',
#   'a',
#   'mesmerising.',
#   'excellent',
#   'very',
#   'very',
#   'very',
#   'the',
#   'very',
#   'in',
#   'the',
#   'very',
#   'very',
#   'cut',
#   'minimum',
#   'fantastic.',
#   'very',
#   'just',
#   'a',
#   'far',
#   'awesome.',
#   'excellent',
#   'good.',
#   'at',
#   'a',
#   'very',
#   'totally',
#   'average.',
#   'breathtakingly',
#   'a',
#   'far',
#   'good',
#   'on',
#   'facing',
#   'full',
#   'extremely',
#   'good',
#   'not',
#   'about',
#   'inaccessible',
#   'really',
#   'the',
#   'one',
#   'an',
#   'good',
#   'meant',
#   'very',
#   'away',
#   'quite',
#   'not',
#   'the',
#   'limited.',
#   'fine',
#   'during',
#   'the',
#   'a',
#   'very',
#   'beauitful',
#   'priceless.',
#   'situated',
#   'priced',
#   '20%,',
#   'too',
#   'too',
#   'closed',
#   'no',
#   'beautiful.',
#   'no',
#   'not',
#   'very',
#   'so',
#   'good.',
#   'too',
#   'very',
#   'also',
#   'located',
#   'an',
#   'really',
#   'very',
#   'bit',
#   'good',
#   'fairly',
#   'very',
#   'quick',
#   'little',
#   'perfect".',
#   'very',
#   'set',
#   'very',
#   'in',
#   'pleasant.',
#   'maintained',
#   'excellent.',
#   'a',
#   'good',
#   'also',
#   'not',
#   'spread',
#   'a',
#   'their',
#   'beautiful,',
#   'that',
#   'available',
#   'not',
#   'cool',
#   'awesome,',
#   'a',
#   'little',
#   'very',
#   'really',
#   'bad',
#   'worth',
#   'the',
#   'no',
#   'good',
#   'very',
#   'the',
#   'average',
#   'not',
#   'in',
#   '11',
#   'just',
#   'very',
#   'spread',
#   'a',
#   'not',
#   'awesome.',
#   'the',
#   'under',
#   'clean.',
#   'very',
#   'not',
#   'very',
#   'fine.',
#   'the',
#   'out',
#   'so',
#   'also',
#   'not',
#   'okay',
#   'food',
#   'very'],
#  'located': ['next', 'in', 'bear', 'in', 'in', 'in'],
#  'next': ['to', 'time.', 'to', 'holidays.'],
#  'to': ['a',
#   'stay',
#   'a',
#   'premium',
#   'premium',
#   'stay',
#   'relax',
#   'relax.',
#   'this',
#   'spend',
#   'spend',
#   'the',
#   'make',
#   'give',
#   'be',
#   'the',
#   'visit',
#   'Munnar',
#   'get',
#   'Rivulet',
#   'be',
#   'stay',
#   'help',
#   'visit',
#   'be',
#   'facilities',
#   'the',
#   'recommend',
#   'Resort',
#   'River',
#   'visit',
#   'be',
#   'say',
#   'family',
#   'a',
#   'go',
#   'Pallivasal',
#   'get',
#   'get',
#   'visit',
#   'celebrate',
#   'anyone',
#   'relax',
#   'be',
#   'the',
#   'remember',
#   'be',
#   'make',
#   'visit',
#   'better',
#   'the',
#   'walk,',
#   'season',
#   'river',
#   'the',
#   'engage',
#   'eat',
#   'resort.',
#   'view',
#   'the',
#   'live',
#   'relax',
#   'September',
#   'visit',
#   'have',
#   'stay',
#   'play',
#   'visit',
#   'pay',
#   'the',
#   'that.',
#   'direct',
#   'rely',
#   'please',
#   'go',
#   'stay',
#   'their',
#   'visit.',
#   'just',
#   'the',
#   'reach',
#   'come',
#   'stay',
#   'stay',
#   'sit',
#   'connect',
#   'friends.',
#   'my',
#   'resort',
#   'be',
#   'stay',
#   'our',
#   'river,',
#   'stay.',
#   'strike.',
#   'stay',
#   'friends',
#   'be',
#   'check',
#   'explore',
#   'serve',
#   'cook',
#   'him.',
#   'say',
#   'go',
#   'this',
#   'get',
#   'but',
#   'all',
#   'the',
#   'keep',
#   'anyone.',
#   'it.',
#   'remove',
#   'get',
#   'visit',
#   'enjoy.',
#   'check',
#   'have',
#   'go',
#   'again',
#   'the',
#   'our',
#   'come',
#   'our',
#   'be',
#   'stay',
#   'prefer',
#   'couples',
#   'resort.',
#   'stay.',
#   'say',
#   'stay,',
#   'get',
#   'commute',
#   'come',
#   'resort',
#   'relax',
#   'have.',
#   'wait',
#   'get',
#   'give',
#   'visit',
#   'leave',
#   'the',
#   'come',
#   'customers.',
#   'visit',
#   'wrap',
#   'plan',
#   'Munnar',
#   'live',
#   'the',
#   'stay',
#   'the'],
#  'a': ['River',
#   'free',
#   'villa',
#   'few',
#   'spa',
#   'little',
#   'swimming',
#   'royal',
#   'big',
#   'wonderful',
#   'three',
#   'tour',
#   'proper',
#   'family,',
#   'pleasant',
#   'good',
#   'bit',
#   'fascinating',
#   'holiday',
#   'short',
#   'great',
#   'better',
#   'nice',
#   'sum',
#   'Resort.',
#   'small',
#   'lot.',
#   'City.',
#   'short',
#   'nice',
#   'flowing',
#   'must',
#   'lot.',
#   'beautiful',
#   'peaceful',
#   'stroll',
#   'great',
#   'great',
#   'prime',
#   'sheer',
#   'lot',
#   'must',
#   'river',
#   'la',
#   'very',
#   'most',
#   'good',
#   'pretty',
#   'lot',
#   'change,',
#   'different',
#   'deterrent',
#   'very',
#   'little',
#   'view',
#   'excellent',
#   'rivulet',
#   'good',
#   'constant',
#   'good',
#   'good',
#   'value',
#   'nice',
#   'veg',
#   'living',
#   'little',
#   'little',
#   'little',
#   'little',
#   'much',
#   'valley,',
#   'good',
#   'quarter',
#   'walk.',
#   'quite',
#   'little',
#   'decent',
#   'simple',
#   'warm',
#   'good',
#   'good',
#   'treat',
#   'separate',
#   'small',
#   'good',
#   'badminton',
#   'club',
#   'dampner',
#   'cute',
#   'wide',
#   'hotel.',
#   'good',
#   'huge',
#   'rivulet',
#   'stay.',
#   'serene',
#   'natural',
#   'big',
#   'fairly',
#   '2',
#   'supervisor',
#   'long',
#   'little',
#   'bit',
#   'children',
#   'small',
#   'very',
#   '4',
#   '4',
#   '2',
#   'resort.',
#   'little',
#   'location',
#   'place',
#   'great',
#   'beautiful',
#   'rental',
#   'bit',
#   'break',
#   'island.',
#   'very',
#   'very',
#   'huge',
#   'rivulet',
#   'lot',
#   'wonderful',
#   'great',
#   'good'],
#  'River': ['and', 'is', 'view,', 'Side', 'facing', 'sound', 'view'],
#  'probably': ['the', 'a'],
#  'the': ['best',
#   'hospitality',
#   'people',
#   'food',
#   'hotel',
#   'morning.',
#   'hotel.',
#   'experiences',
#   'thirst',
#   'Rivulet',
#   'stay',
#   'view',
#   'road,',
#   'river',
#   'usual',
#   'City',
#   'City',
#   'short',
#   'place',
#   'best.',
#   'spa',
#   'other',
#   'balcony',
#   'middle',
#   'staff.',
#   'ambiance',
#   'temperature',
#   'resort',
#   'when',
#   'beautiful',
#   'best',
#   'best',
#   'villa',
#   'running',
#   'bottom',
#   'Valley.',
#   'staff',
#   'best',
#   'morning,',
#   'fresh',
#   'other',
#   'end',
#   'villa.',
#   'resort',
#   'road',
#   'resort,',
#   'management',
#   'road',
#   'water',
#   'stay',
#   'best',
#   'prices',
#   'best',
#   'river.',
#   'hustle',
#   'birds',
#   'property.',
#   'Ayurvedic',
#   'resort.',
#   'help',
#   'river.',
#   'water',
#   'resort',
#   'distance',
#   'location.',
#   '2',
#   'stay',
#   'best',
#   'river',
#   'bed',
#   'justice',
#   'real',
#   'place.',
#   'breakfast',
#   'staff',
#   'employee.',
#   'night.',
#   'traffic',
#   'crowd.',
#   'hotel',
#   'bank',
#   'river.',
#   'river',
#   'staff',
#   'trip',
#   'property',
#   'time',
#   'resort.',
#   'rooms',
#   'warmer',
#   'resort',
#   'park',
#   'trek',
#   'property',
#   'flip',
#   'river',
#   'money',
#   'actual',
#   'resort',
#   'river',
#   'Moselberg',
#   'morning,',
#   'temple',
#   'walk',
#   'guide',
#   'huge',
#   'resort-',
#   'fauna',
#   'audience',
#   'trek',
#   'plants',
#   'resort-',
#   'market',
#   'expectation',
#   'room!',
#   'way',
#   'town',
#   'river',
#   'room',
#   'photos.',
#   'place',
#   'resort.',
#   'location',
#   'water',
#   'activities',
#   'resort.',
#   'resort.',
#   'location.',
#   'honeymoon',
#   'room',
#   'river',
#   'river',
#   'nearby',
#   'stay',
#   'winter.',
#   'a',
#   'kids',
#   'lake',
#   'hotel',
#   'facility',
#   'hotel',
#   'only',
#   'location',
#   'main',
#   'room',
#   'river',
#   'higher',
#   'food',
#   'management',
#   'money',
#   'villa,',
#   'rooms',
#   'price',
#   'doorbell',
#   'room.',
#   'restaurant',
#   'correct',
#   'hotel',
#   'service',
#   'guests',
#   'staff',
#   'money,',
#   'price',
#   'pics',
#   'location,',
#   'mountains',
#   'same',
#   'morning,',
#   'attitude',
#   'resort',
#   'entire',
#   'staff',
#   'chef',
#   'service',
#   'hotel',
#   'city',
#   'best',
#   'hotel',
#   'river',
#   'peaceful',
#   'balcony',
#   'stream',
#   'forest',
#   'beautiful',
#   'outskirts',
#   'ride',
#   'best',
#   'balcony',
#   'view',
#   'manager',
#   'fishing',
#   'Rivulet',
#   'ambience',
#   'resort',
#   'river.',
#   'stay.',
#   'back',
#   'balcony.',
#   'owner',
#   'guests.',
#   'following',
#   'bathrooms',
#   'quality',
#   'ambiance',
#   'resort.',
#   'resort',
#   'river',
#   'cottage,',
#   'staff.',
#   'hospitality.',
#   'staff',
#   'resort.',
#   'local',
#   'cuisines',
#   'chef',
#   'culture',
#   'menu',
#   'chef',
#   'resort',
#   'case',
#   'area.',
#   'windy',
#   'flavors',
#   'entrance',
#   'road.',
#   'city,',
#   'rooms.',
#   'location',
#   'season',
#   'tea',
#   'room',
#   'way.',
#   'hotel.',
#   'walk',
#   'Spice',
#   'operation',
#   'road',
#   'hotel',
#   'view',
#   'location,',
#   'food,',
#   'expectation',
#   'cottages!',
#   'cottages',
#   'place!',
#   'WiFi',
#   'nice',
#   'hotel',
#   'enjoying',
#   'holidays.',
#   'perfect',
#   'food',
#   'best',
#   'small',
#   'first',
#   'stay.',
#   'evening',
#   'hospitality',
#   'place',
#   'river',
#   'property',
#   'reception',
#   'hotel',
#   'hotel',
#   'stay.',
#   'SPA',
#   'bar',
#   'rivulet',
#   'hide',
#   'mist',
#   'staff',
#   'guest',
#   'whole',
#   'most',
#   'start',
#   'stay',
#   'end',
#   'place,',
#   'property',
#   'mark',
#   'other.',
#   'hotel',
#   'hotel',
#   'stay'],
#  'best': ['time',
#   'prices.',
#   'if',
#   'among',
#   'in',
#   'aspect,',
#   'you',
#   'Resort',
#   'view',
#   'time',
#   'resort',
#   'part',
#   'part',
#   'hotels'],
#  'time': ['to', 'with', 'with', 'was', 'at', 'spend', 'at', 'to'],
#  'there': ['is',
#   'Peaceful',
#   'was',
#   'to',
#   'were',
#   'are',
#   'should',
#   'for',
#   'to',
#   'part.',
#   'for',
#   'from',
#   'is',
#   'is',
#   'is',
#   'is',
#   'and'],
#  'during': ['monsoons', 'inhaling', 'our', 'the', 'monsoon.', 'the'],
#  'monsoons': ['or'],
#  'or': ['post', 'an', 'couple', 'couple,', 'not'],
#  'post': ['monsoons.'],
#  'monsoons.': ['However'],
#  'However': ['we', 'lack', 'fish,'],
#  'we': ['visited',
#   'got',
#   'enjoyed',
#   'stayed',
#   'liked',
#   'had',
#   'enjoyed',
#   'managed',
#   'actually',
#   'lost',
#   'had',
#   'also',
#   'ordered',
#   'had',
#   'got',
#   'informed',
#   'stayed,',
#   'enjoy',
#   'rarely',
#   'had',
#   'loved',
#   'have.',
#   "don't",
#   'have',
#   'wanted',
#   'have',
#   'are',
#   'had',
#   'are',
#   'enjoyed,',
#   'like',
#   'extended'],
#  'visited': ['in'],
#  'in': ['february',
#   'the',
#   'your',
#   'the',
#   'Munnar.',
#   'house',
#   'Munnar',
#   'pleasant',
#   'breakfast',
#   'buffet',
#   'Rivulet.',
#   'Munnar',
#   'Munnar.',
#   'this',
#   'the',
#   'Munnar',
#   'Munnar',
#   'this',
#   'every',
#   'very',
#   'tamarind',
#   'the',
#   'balcony',
#   'service.',
#   'the',
#   'rivulet',
#   'Munnar',
#   'easy',
#   'future.',
#   'that',
#   'Rivulet.',
#   'the',
#   'serving',
#   'Munnar',
#   'river',
#   'the',
#   'Munnar',
#   'Rivulet,',
#   'the',
#   'food',
#   'the',
#   'the',
#   'my',
#   'downtown',
#   'the',
#   'a',
#   'front',
#   'the',
#   'the',
#   'the',
#   'the',
#   'river',
#   'calm',
#   'love',
#   'the',
#   'rice',
#   'valley',
#   'Munnar',
#   'a',
#   'the',
#   'the',
#   'helping',
#   'deciding',
#   'valley',
#   'the',
#   'the',
#   'the',
#   'the',
#   'childrens',
#   'Munar',
#   'between',
#   'Munnar.',
#   'mountain',
#   'a',
#   'the',
#   'making',
#   'India',
#   'north',
#   'the',
#   'our',
#   'the',
#   'the',
#   '3',
#   'this',
#   'December',
#   'the',
#   'our',
#   'a',
#   'Munnar',
#   'Chithirapuram',
#   'the',
#   'room',
#   'the',
#   'the',
#   'our',
#   'Munnar',
#   'words.',
#   'this',
#   'this',
#   'Rivulet'],
#  'february': ['end'],
#  'end': ['and', 'overall.', 'was'],
#  'still': ['loved', 'housekeeping', 'had'],
#  'loved': ['it', 'ones', 'ones', 'the', ':D)', 'them.', 'my'],
#  'it': ['because',
#   'was',
#   'special.',
#   'would',
#   'can',
#   'Awesome',
#   'is',
#   'is',
#   'is',
#   'and',
#   'was',
#   'is',
#   ':',
#   'had',
#   'is',
#   'is',
#   'to',
#   'a',
#   'was',
#   'was',
#   'was.',
#   'was',
#   'was',
#   'are',
#   'really',
#   'is',
#   'really',
#   'is'],
#  'because': ['of', 'the', 'it', 'table'],
#  'hospitality': ['of', ':', 'and', 'and'],
#  'people': ['there.', 'used', 'who', 'would', 'towards', 'at'],
#  'there.': ['We', 'If', 'Excellent', 'cottage,', 'Not', 'What', 'Pleasant'],
#  'We': ['got',
#   'thought',
#   'booked',
#   'had',
#   'stayed',
#   'also',
#   'tried',
#   'had',
#   'whole',
#   'had',
#   'enjoyed',
#   'also',
#   'had',
#   'got',
#   'had',
#   'stayed',
#   'kept',
#   'only',
#   'were',
#   'stayed',
#   'had',
#   'would',
#   'arrived',
#   'were',
#   'have',
#   'really',
#   'will',
#   'could',
#   'had',
#   'planned'],
#  'got': ['a', 'free', 'bit', 'a', 'paper', 'upset'],
#  'free': ['upgrade', 'upgrade'],
#  'upgrade': ['to', 'to', 'to'],
#  'villa': ['and', 'balcony'],
#  'very': ['beautiful.',
#   'courteous',
#   'much',
#   'close',
#   'few,',
#   'kind.',
#   'courteous',
#   'friendly.',
#   'happy',
#   'much.',
#   'good.',
#   'quick',
#   'good',
#   'nice.',
#   'good.',
#   'less',
#   'good',
#   'welcoming.',
#   'less',
#   'courteous',
#   'bad',
#   'well',
#   'expensive',
#   'minimum.',
#   'well',
#   'patient',
#   'friendly,',
#   'friendly.',
#   'late',
#   'friendly,',
#   'satisfying',
#   'good.',
#   'good',
#   'helpful',
#   'well',
#   'bad.',
#   'good.',
#   'supportive',
#   'far',
#   'good',
#   'good',
#   'disappointed',
#   'good',
#   'much',
#   'nice...',
#   'good',
#   'attractive',
#   'clean',
#   'spacious',
#   'nice',
#   'good',
#   'courteous',
#   'pleasant',
#   'warm,',
#   'cooperative.',
#   'well',
#   'memorable.',
#   'polite',
#   'well,',
#   'hard',
#   'friendly',
#   'bad',
#   'bad',
#   'good.',
#   'friendly.',
#   'good.',
#   'soon.',
#   'good.',
#   'good',
#   'good',
#   'good',
#   'nice',
#   'friendly',
#   'good',
#   'good.',
#   'good.',
#   'good.',
#   'poor.',
#   'hygienic',
#   'good.',
#   'good.',
#   'tasty.',
#   'far',
#   'nice',
#   'co',
#   'risky',
#   'nice.'],
#  'beautiful.': ['The', 'There', 'The', 'There', 'The', 'The', 'There', 'The'],
#  'has': ['a',
#   'water',
#   'few',
#   'its',
#   'excellent',
#   'its',
#   'overcome',
#   'great',
#   'a'],
#  'few': ['activities', 'in', 'stairs.', 'tea'],
#  'activities': ['but', 'in', 'with', 'in', 'like'],
#  'but': ['nothing',
#   'we',
#   'food',
#   'is',
#   'it',
#   'it',
#   'stay',
#   'considering',
#   'hotel',
#   'the',
#   "it's",
#   'quality',
#   'price',
#   'on',
#   'it',
#   'the',
#   'that',
#   'not',
#   'might',
#   'the',
#   'services',
#   'can',
#   'too',
#   'still',
#   'he',
#   'there',
#   'a',
#   'not',
#   'generally',
#   'expensive.',
#   'lack',
#   'nice',
#   'the',
#   'the',
#   'dinner',
#   'poor',
#   'the',
#   'some',
#   'with',
#   'I',
#   'I',
#   'I',
#   'still',
#   'as',
#   'the',
#   'personally',
#   'the',
#   'little',
#   'it',
#   'if',
#   'that',
#   'main',
#   'after'],
#  'nothing': ['extraordinary.', 'nearby'],
#  'extraordinary.': ['Has'],
#  'Has': ['a', 'nice', 'a'],
#  'spa': ['where',
#   'a',
#   'services',
#   'at',
#   'services',
#   'rooms.',
#   'service',
#   'and'],
#  'where': ['you'],
#  'you': ['can',
#   'will',
#   'are',
#   'can',
#   'wake',
#   'are',
#   'have',
#   'will',
#   'upset',
#   'can',
#   'feel',
#   'have',
#   'go',
#   'ask-',
#   'need',
#   'are',
#   'will',
#   'will',
#   'can',
#   'pay.',
#   'pay.',
#   'are',
#   'cannot',
#   'will',
#   'a',
#   'feel',
#   'are',
#   "don't",
#   'can',
#   'do'],
#  'can': ['get',
#   'be',
#   'hear',
#   'literally',
#   'make',
#   'get.',
#   'be',
#   'see',
#   'be',
#   'improve',
#   'do',
#   'get',
#   'expect',
#   'have',
#   'offer',
#   'be',
#   'improve',
#   'also'],
#  'get': ['some',
#   'surrounded',
#   'vegetarian',
#   'some',
#   'a',
#   'to',
#   'car',
#   'value',
#   'relax',
#   'rickshaw',
#   'my',
#   'WiFi'],
#  'some': ['ayurvedic',
#   'in',
#   'indoor',
#   'food',
#   'more',
#   'good',
#   'extent',
#   'of',
#   'breakfast'],
#  'ayurvedic': ['massages.'],
#  'massages.': ['The'],
#  'were': ['very',
#   'excellent,',
#   'awesome.',
#   'not',
#   'more',
#   'very',
#   'excellent.',
#   'good',
#   'well',
#   'friendly',
#   'very',
#   'A/cs',
#   'very',
#   'good',
#   'good',
#   'really',
#   'from',
#   'very',
#   'damn',
#   'courteous,',
#   'very',
#   'spacious',
#   'marvelous',
#   'given',
#   'so',
#   'also',
#   'so',
#   'comfortable',
#   'more',
#   'good.',
#   'clean.',
#   'helpful.',
#   'good,',
#   'very',
#   'huge',
#   'river',
#   'very',
#   'unable',
#   'very',
#   'marvelous',
#   'also',
#   'very',
#   'very'],
#  'courteous': ['and', 'and', 'and', 'and', 'and', 'and', 'staff', 'and'],
#  'made': ['us', 'better', 'the', 'you', 'a', 'our', 'it.', 'our'],
#  'us': ['feel', 'valuable', 'in', 'they', 'about', 'two', 'to', 'and', 'what'],
#  'feel': ['at', 'it', 'the', 'in', 'like', 'one', 'awesome'],
#  'at': ['home.',
#   'best',
#   'the',
#   'Rivulet.',
#   'lower',
#   'Rivulet',
#   'Munnar',
#   'the',
#   'night',
#   'hotel,',
#   'Rivulet',
#   'the',
#   'archery',
#   'a',
#   'The',
#   '9',
#   'the',
#   'the',
#   'all',
#   'all.',
#   '8:00).',
#   'place',
#   'the',
#   'the',
#   'all.',
#   '8',
#   'the',
#   'the',
#   'all',
#   'all.',
#   'Rivulet'],
#  'home.': ['We', 'The'],
#  'thought': ['the'],
#  "wasn't": ['that', 'good'],
#  'that': ['great',
#   'was',
#   'everything',
#   'long.',
#   'resort',
#   'I',
#   'can',
#   'good.',
#   'I',
#   'the',
#   'we',
#   'much',
#   'may',
#   'was',
#   'place',
#   'fresh.',
#   'everything',
#   'it'],
#  'great': ['and',
#   'location',
#   'view.',
#   'food,',
#   'food.',
#   'experience.',
#   'ambience',
#   'view.',
#   'view',
#   'experience',
#   'with',
#   'show',
#   'welcome,',
#   'and',
#   'view',
#   'view.',
#   'place',
#   'place',
#   'experience.',
#   'view.',
#   'experience'],
#  'little': ['over',
#   'away',
#   'high',
#   'out',
#   'bit',
#   'faraway',
#   'overpriced',
#   'far',
#   'far',
#   'let',
#   'more',
#   '(mind',
#   'one)',
#   'traffic',
#   'late,',
#   'far'],
#  'over': ['priced.', 'there.', 'a', 'a'],
#  'priced.': ['Good', 'Food'],
#  'Good': ['stay,',
#   'services.',
#   'resort',
#   'food,',
#   'Stay',
#   'ambience',
#   'stay,',
#   'and',
#   'memorable',
#   ':',
#   'hotel,',
#   'Stay',
#   'Stay',
#   'Stay',
#   'view,',
#   ':',
#   'Stay',
#   'food',
#   'place',
#   'resort',
#   'rooms',
#   'resort',
#   'location.',
#   'service.',
#   'resort',
#   'view',
#   'hotel',
#   'rooms,',
#   'people.',
#   'security',
#   'beautiful',
#   ':',
#   'Stay',
#   'ambiance.',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'Stay',
#   'attractions',
#   'Stay',
#   'hospitality,',
#   'Stay',
#   'Stay',
#   'Stay',
#   'rooms,',
#   'Stay',
#   'Stay',
#   'location,',
#   'Stay',
#   'Stay',
#   'location',
#   'Stay'],
#  'stay,': ['great',
#   'great',
#   'staff',
#   'location,',
#   'friendly',
#   'we',
#   'enjoyed.',
#   'though',
#   'friendly'],
#  'location': [':',
#   ':',
#   'was',
#   'and',
#   ':',
#   'was',
#   'very',
#   ':',
#   ':',
#   'and',
#   ':',
#   'and',
#   'was',
#   'and',
#   'offers',
#   'is',
#   'close',
#   'of',
#   ':',
#   'of',
#   'and',
#   'and',
#   '!.',
#   'of',
#   'good',
#   'which',
#   'is',
#   'is',
#   'is',
#   'is',
#   'complimented',
#   '(but',
#   'with',
#   'breathtaking',
#   'and',
#   'is',
#   'as',
#   'was',
#   'is,',
#   'it',
#   'was',
#   'for',
#   ':',
#   'but',
#   '.',
#   ',',
#   'with',
#   ':',
#   'and',
#   'of'],
#  'hotel': ['were',
#   'is',
#   ':',
#   'for',
#   'a',
#   'in',
#   'in',
#   'Very',
#   'is',
#   ':',
#   'is',
#   'is',
#   'and',
#   'and',
#   'in',
#   'for',
#   'side',
#   'was',
#   'with',
#   'restaurant',
#   'is',
#   'was',
#   'by',
#   'look',
#   'but',
#   'to',
#   'is',
#   'was',
#   'to',
#   'to',
#   'in',
#   'was',
#   'was',
#   ',',
#   ',',
#   'is'],
#  'excellent,': ['only'],
#  'only': ['thing',
#   'thing',
#   'turn',
#   'disappointment',
#   'downside',
#   '...',
#   'went',
#   'thing',
#   'the',
#   'little',
#   'as'],
#  'thing': ['missing',
#   'I',
#   'I',
#   'is',
#   'is',
#   'was',
#   'what',
#   'was',
#   'was',
#   'missing',
#   'from',
#   'is'],
#  'missing': ['was', 'is'],
#  'swimming': ['pool.', 'pool', 'pool,'],
#  'pool.': ['Free'],
#  'Free': ['upgrade'],
#  'premium': ['suite', 'one.'],
#  'suite': [':', 'is', 'decoration', 'was'],
#  'booked': ['a', 'for', 'Honeymoon'],
#  'royal': ['suite,', 'suites'],
#  'suite,': ['but'],
#  'one.': ['Rooms', 'Being', 'There', 'Loads'],
#  'Rooms': ['have',
#   'and',
#   'was',
#   'are',
#   'and',
#   'and',
#   'are',
#   'were',
#   'were',
#   'are',
#   'are'],
#  'have': ['nice',
#   'fun',
#   'river',
#   'been',
#   'been',
#   'been',
#   'small',
#   'good',
#   'buffet',
#   'helped.',
#   'was',
#   'seen.',
#   'one',
#   'experienced.',
#   'noisy',
#   'both',
#   'been',
#   'been',
#   'tea',
#   'more',
#   'been',
#   'fun',
#   'nice',
#   'trekking',
#   'pictures',
#   'to',
#   'much',
#   'to',
#   'seen',
#   'great',
#   'visited.',
#   'marks/stains',
#   'traveled',
#   'managed',
#   'no',
#   'not',
#   'on',
#   'small',
#   'a'],
#  'nice': ['view',
#   'activities',
#   'staff,',
#   'food,',
#   'hotel',
#   'Resort',
#   'and',
#   'river',
#   'property.',
#   'villas',
#   'location',
#   'views.',
#   'to',
#   'sleep,',
#   'views',
#   'river',
#   'but',
#   'guesthouse',
#   'welcome.',
#   '(they',
#   'and',
#   'and',
#   'experience.',
#   'view.',
#   'views',
#   'and',
#   'resort.',
#   'location',
#   'location',
#   'staff.',
#   'built'],
#  'view': ['of',
#   'from',
#   'was',
#   ':',
#   'but',
#   ':',
#   'from',
#   'is',
#   'and',
#   'from',
#   'was',
#   'was',
#   'from',
#   'with',
#   ':',
#   'of',
#   'of',
#   'that',
#   'room',
#   'will',
#   'from',
#   'Decent',
#   'right',
#   'of',
#   'of',
#   'from',
#   ':',
#   'from',
#   'and',
#   ':',
#   'of',
#   'and',
#   'was',
#   'is',
#   'was',
#   'from'],
#  'River.': ['You', 'Staff'],
#  'You': ['will', 'might', 'can', 'could', 'may'],
#  'will': ['enjoy',
#   'definitely',
#   'have',
#   'definitely',
#   'repeat).',
#   'be',
#   'take',
#   'have',
#   'have',
#   'have',
#   'definitely',
#   'meet',
#   'go',
#   'also',
#   'recommend'],
#  'enjoy': ['birds', 'your', 'nature', 'most', 'travelling'],
#  'birds': ['singing', 'chirping,', 'chirping,', 'chirping'],
#  'singing': ['in', 'in'],
#  'morning.': ['You'],
#  'might': ['spot', 'be'],
#  'spot': ['few', 'for'],
#  'your': ['balcony.',
#   'stay.',
#   'loved',
#   'loved',
#   'breath.',
#   'own',
#   'money',
#   'mind',
#   'stay',
#   'staff',
#   'resort'],
#  'balcony.': ['There', 'Good', 'Activities', 'The', 'The'],
#  'There': ['are',
#   'was',
#   'were',
#   'is',
#   'is',
#   'are',
#   'toiletries',
#   'is',
#   'is',
#   'is',
#   'is'],
#  'other': ['activities',
#   'than',
#   'indoor',
#   'commercial',
#   'amenities',
#   'side',
#   'period,',
#   'most',
#   'things',
#   'vegetarian'],
#  'hotel.': ['It', 'Fraud', 'Excellent', 'Good', 'Location', 'It'],
#  'It': ['is',
#   'was',
#   'will',
#   'would',
#   'is',
#   'was',
#   'was',
#   'was',
#   'may',
#   'was',
#   'was',
#   'is',
#   'is',
#   'was',
#   'was',
#   'was',
#   'took',
#   'was',
#   'is',
#   'has',
#   'was',
#   'was'],
#  'big': ['property,', 'and', 'sitting', 'and'],
#  'property,': ['you'],
#  'definitely': ['enjoy',
#   'fulfill',
#   'the',
#   'love',
#   'do',
#   'like',
#   'recommend',
#   'recommending',
#   'come',
#   'recommend'],
#  'stay.': ['',
#   'Suite',
#   'Recommend',
#   'Great',
#   'Could',
#   'Very',
#   'Great',
#   'Kids',
#   'Overall',
#   'Food',
#   'A',
#   'Room',
#   'I',
#   'Hospitality',
#   'It',
#   'Worth',
#   'Good',
#   'Plus',
#   'Good',
#   'Average',
#   'good',
#   'Very',
#   'The'],
#  '': [':'],
#  'Best': ['Resort', 'place', 'stay', 'in', 'stay', 'of', 'resort'],
#  'prices.': ['Treks'],
#  'Treks': ['n'],
#  'n': ['River', 'most'],
#  'main': ['attraction.',
#   'area,',
#   'city',
#   'Munnar',
#   'Munnar',
#   'city,',
#   'thing'],
#  'attraction.': ['Hotel'],
#  'Hotel': ['provides', 'location', 'located', 'is', 'staff'],
#  'provides': ['many'],
#  'many': ['leisure', 'restaurants', 'more'],
#  'leisure': ['activities.'],
#  'activities.': ['Kids', 'It'],
#  'Kids': ['will', 'park,', 'had'],
#  'fun': ['there', 'as'],
#  'Peaceful': ['and', 'and'],
#  'serene': ['location', 'surrounding', 'location', '&', 'atmosphere,'],
#  'Rivulet': ['Resort',
#   'Resort',
#   'Resort.',
#   'experience',
#   ':',
#   'Resort',
#   ':',
#   'Resort',
#   'fabulous',
#   ':',
#   ':',
#   'is',
#   'is',
#   'Resort',
#   'Resort',
#   'were',
#   'Resort',
#   'resort',
#   'was',
#   'for',
#   'was'],
#  'wonderful': ['place', 'host,', ':', 'experience'],
#  'place': ['to',
#   'for',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'on',
#   'to',
#   'to',
#   'to',
#   'with',
#   'is',
#   'to',
#   'are',
#   'for',
#   'to',
#   'to',
#   'is',
#   'to',
#   'to',
#   'to',
#   'to',
#   'again',
#   'which',
#   'to',
#   'for',
#   'with',
#   'is',
#   'once',
#   'again.'],
#  'Munnar.': ['Away',
#   'Amazing',
#   'The',
#   'They',
#   'but',
#   'The',
#   'Food',
#   'Has',
#   'Beautiful.',
#   'Food',
#   'The'],
#  'Away': ['from', 'from'],
#  'from': ['city',
#   'rooms',
#   'restaurant',
#   'Munnar',
#   'the',
#   'here',
#   'the',
#   'buzzle',
#   'balcony',
#   'a',
#   'the',
#   'Munnar',
#   'balcony.',
#   'Munnar.',
#   'the',
#   'Munnar',
#   'cottage',
#   'Munnar',
#   'Munnar.',
#   'Munnar',
#   'the',
#   'front',
#   'rooms-',
#   'the',
#   'the',
#   'the',
#   'balcony.',
#   'main',
#   'Munnar',
#   'villas',
#   'July',
#   'the',
#   'balcony,',
#   'morning',
#   'the',
#   'Munnar.',
#   'Bangalore.',
#   'tourist',
#   'Arab',
#   'main',
#   'city',
#   'main',
#   'MMT',
#   'city',
#   'proper',
#   'Munnar',
#   'the',
#   'the',
#   'anywhere.',
#   'Munnar.',
#   'the',
#   'regular',
#   'them.',
#   'munnar',
#   'Munnar.Best',
#   'Munnar',
#   'this',
#   'Munnar',
#   'our',
#   'Munnar',
#   'that',
#   'the',
#   'Munnar'],
#  'city': ['hustle',
#   'altogether',
#   'life',
#   'life',
#   'attractions',
#   'walks',
#   'and'],
#  'hustle': ['bustle', 'bustle,'],
#  'bustle': ['near'],
#  'near': ['river.', 'to', 'to', 'by', 'the', 'by', 'to', 'to'],
#  'river.': ['Best', 'In', 'Cut', 'The', 'The', 'Bamboo'],
#  'for': ['couples.',
#   'everyone.',
#   'couples',
#   'me',
#   'peace',
#   'a',
#   'me.',
#   'short',
#   'group',
#   'family',
#   'them.',
#   'a',
#   'the',
#   'relaxation.',
#   'veg,',
#   'couple',
#   'a',
#   'money.',
#   'families.',
#   'money.',
#   'people',
#   'breakfast.',
#   'a',
#   '8.',
#   'whatever',
#   'bon-fire,',
#   'ripe',
#   'one-two',
#   'relaxed',
#   'money.',
#   'couples',
#   'people',
#   'any',
#   'actual',
#   'family',
#   'the',
#   "children's",
#   'your',
#   'money',
#   'a',
#   'the',
#   'vegetarian',
#   'money.',
#   'getting',
#   'kids',
#   'money.',
#   'it',
#   'better',
#   'this',
#   'this',
#   'three',
#   '2',
#   'each',
#   'getting',
#   'a',
#   'quite',
#   'family',
#   'next',
#   'family',
#   'family',
#   '3',
#   'suggesting',
#   'most',
#   'a',
#   'a',
#   'one',
#   'us',
#   'the',
#   'the',
#   'city',
#   '2',
#   'this.',
#   'money.',
#   'accommodation',
#   'good',
#   'rivulet',
#   'vegetarians.',
#   'one',
#   'another'],
#  'couples.': ['Good'],
#  'services.': ['Rivulet', 'Park'],
#  'three': ['days', 'days'],
#  'days': ['trip', 'here.', 'stay', 'during', 'from', 'and', 'and', 'to'],
#  'trip': ['and', '2019', 'really', 'we', 'and', 'to'],
#  'experiences': ['are'],
#  'awesome.': ['It',
#   'Quiet',
#   'The',
#   'One',
#   'Great',
#   'Very',
#   'Over',
#   'They',
#   'Excellent',
#   'Only'],
#  'fulfill': ['the'],
#  'thirst': ['of'],
#  'tour': ['lover.', 'is'],
#  'lover.': ['The'],
#  'incomplete': ['without'],
#  'without': ['staying', 'our'],
#  'staying': ['at', 'by', 'there.', 'in'],
#  'Resort.': ['The', 'Wonderful', 'Location', 'Worst', 'Nice'],
#  'provide': ['some'],
#  'house': ['activity', 'keeping', 'keeping'],
#  'activity': ['such'],
#  'such': ['as', 'activities.', 'as', 'a', 'a'],
#  'as': ['nature',
#   'much',
#   'I',
#   'they',
#   'the',
#   'my',
#   'a',
#   'compared',
#   'well',
#   'the',
#   'their',
#   'the',
#   "didn't",
#   'advertised',
#   'no',
#   'there',
#   'well.',
#   'we',
#   'Boom',
#   'well.',
#   'average',
#   'we',
#   'all',
#   'its',
#   'they',
#   'for',
#   'soon',
#   'possible.',
#   'it',
#   'Rivulet'],
#  'nature': ['walk,', ':', 'view', 'Resort', 'walk', ':', 'walk.'],
#  'walk,': ['cycling,', 'walk', 'Archery,'],
#  'cycling,': ['bamboo'],
#  'bamboo': ['rafting', 'rafting'],
#  'rafting': ['and', 'etc', 'and'],
#  'also': ['some',
#   'very',
#   'and',
#   'enjoyed',
#   'good.',
#   'requested',
#   'guides',
#   'got',
#   'available',
#   'very',
#   'very',
#   'good',
#   'be',
#   'recommend',
#   'so',
#   'was',
#   'not'],
#  'indoor': ['outdoor', 'games,', 'games'],
#  'outdoor': ['games'],
#  'games': ['equipments.', 'as', 'except'],
#  'equipments.': ['Excellent'],
#  'Amazing': ['location,',
#   'place',
#   'place',
#   'place,',
#   'stay.',
#   'river/waterfall',
#   'location.'],
#  'location,': ['view,',
#   'high',
#   'helpful',
#   'River',
#   'excellent',
#   'views',
#   'great',
#   'because',
#   'great',
#   'good',
#   'view',
#   'there',
#   'nice'],
#  'view,': ['staff,', 'gardens', 'good', 'good', 'and', 'like', 'rooms,'],
#  'staff,': ['comfy', 'nice', 'good', 'prompt', 'Mr', 'all'],
#  'comfy': ['room'],
#  'room': ['and',
#   'was',
#   'was',
#   'as',
#   'had',
#   'in',
#   'service.',
#   'and',
#   'is',
#   'as',
#   'decoration',
#   'is',
#   'service',
#   'and',
#   'but',
#   'was',
#   'was',
#   'which',
#   ':',
#   '&',
#   'with',
#   'and',
#   'does',
#   'location',
#   'was',
#   'as',
#   'on',
#   'was',
#   'but',
#   'given'],
#  'much': ['recommended',
#   'issue',
#   'cooler',
#   'cheaper',
#   'expected.',
#   'and',
#   'options',
#   'better',
#   'money.',
#   'money',
#   'pleasant.',
#   'in',
#   'in'],
#  'recommended': ['for', 'for', 'at', 'to'],
#  'everyone.': ['Awesome'],
#  'Awesome': ['place',
#   'location',
#   'scenic',
#   'hotel',
#   'location',
#   'is',
#   'hotel'],
#  'relax': [':', ':', '&', 'yourself.', 'and'],
#  'I': ['like',
#   'could',
#   'want',
#   'always',
#   'recommend',
#   'would',
#   "didn't",
#   'have',
#   'really',
#   'have',
#   'felt',
#   'experienced',
#   'understand',
#   'shd',
#   'would',
#   'fould',
#   'paid',
#   'would',
#   'was',
#   'have',
#   'stayed',
#   'would',
#   'have',
#   'stayed',
#   'with',
#   'do',
#   'have',
#   'would',
#   'believe',
#   'think',
#   'just',
#   'got',
#   'feel',
#   'would',
#   'really',
#   'just',
#   'would',
#   'do',
#   'had',
#   'strongly',
#   'will',
#   'feel'],
#  'Rivulet.': ['The', 'Excellent', 'I', 'The'],
#  'rooms': ['and',
#   'were',
#   'have',
#   'was',
#   'are',
#   'and',
#   'are',
#   'with',
#   'are',
#   'are',
#   'with',
#   'have',
#   'are',
#   'with',
#   'which',
#   'with',
#   'were',
#   'are',
#   ':',
#   'were',
#   'are',
#   'with',
#   'were',
#   'are',
#   'never',
#   'and',
#   'were',
#   'are'],
#  'Quiet': ['and'],
#  'calm': ['place', '&'],
#  'relax.': ['The'],
#  'river': ['and',
#   'view.',
#   'and',
#   'view,',
#   'view',
#   'makes',
#   'outside.',
#   'flowing',
#   'view',
#   'and',
#   'is',
#   'is',
#   '(river',
#   'bridge,',
#   '(bon-fire',
#   'flowing',
#   'view',
#   ':',
#   'which',
#   'before',
#   'by',
#   'just',
#   'view,',
#   'facing',
#   'behind',
#   'facing',
#   'facing',
#   'flowing'],
#  'mountain': ['view', 'than'],
#  'service': ['was',
#   'Nice',
#   'also',
#   'is',
#   'and',
#   'and',
#   'everything',
#   'was',
#   'is',
#   'are',
#   "wasn't",
#   'was',
#   'is',
#   'reasonably',
#   'good',
#   'is',
#   'was'],
#  'nice.': ['Other', 'Good', 'Good', 'Loved', 'Could'],
#  'Other': ['than', 'services'],
#  'than': ['the', 'that', 'this', 'others'],
#  'road,': ['to'],
#  'this': ['location',
#   'hotel',
#   'is',
#   'Resort',
#   'hotel.',
#   'Resort.',
#   'destination',
#   'resort',
#   'resort',
#   'was',
#   "shouldn't",
#   'specific',
#   'place.',
#   'one.',
#   'one,',
#   'resort',
#   'resort',
#   'is',
#   'resort.',
#   'resort.',
#   'resort.',
#   'place',
#   'hotel',
#   'place',
#   'place.',
#   'beautiful',
#   'hotel.',
#   'hotel.'],
#  'bad,': ['everything'],
#  'everything': ['else',
#   'was',
#   'was',
#   'is',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'is'],
#  'else': ['here', 'in'],
#  'here': ['is', 'for', 'and', 'Food', 'as'],
#  'place,': ['must', 'very', 'value', 'cozy', 'nice', 'view,'],
#  'must': ['visit', 'try.', 'experience'],
#  'visit': ['for',
#   'again',
#   'again',
#   'once',
#   'again.',
#   'again',
#   'with',
#   'Munnar',
#   'soon',
#   'this',
#   'again.',
#   'again,',
#   'that'],
#  'couples': ['in', 'who', 'and'],
#  'A': ['comfortable', 'beautiful', 'really', 'very', 'large', 'nice', 'great'],
#  'comfortable': ['stay', 'stay', 'and', ':'],
#  'pleasant': ['suit,', 'stay', 'stay', 'and', 'staff,', 'stay.', 'and', 'and'],
#  'suit,': ['nice'],
#  'with': ['well-behaved',
#   'your',
#   'your',
#   'serene',
#   'a',
#   'my',
#   'more',
#   'my',
#   'great',
#   'mountains,',
#   'bird',
#   'river.',
#   'sound',
#   'some',
#   'beautiful',
#   'river',
#   'a',
#   'the',
#   'family',
#   'nice',
#   'pretty',
#   'no',
#   'okay',
#   'courteous',
#   'a',
#   'kids',
#   'family',
#   'this',
#   'my',
#   'value',
#   'a',
#   'several',
#   'the',
#   'a',
#   'the',
#   "'Rivulet'",
#   'a',
#   'my',
#   'nature',
#   'a',
#   'a',
#   'the',
#   'a',
#   'us',
#   'modern',
#   'spacious',
#   'a',
#   'superb',
#   'my',
#   'full',
#   'nature.',
#   'the',
#   'the',
#   'the',
#   'balcony.',
#   'our',
#   'the',
#   'nice',
#   'the',
#   'all',
#   'Rivulet',
#   'very'],
#  'well-behaved': ['staff.'],
#  'staff.': ['Excellent',
#   'Will',
#   'Good',
#   'Enjoyed',
#   'Food',
#   'Has',
#   'I',
#   'Good',
#   'Loved',
#   'Good'],
#  'Nice': ['ambience,',
#   'hotel',
#   'hotel',
#   'beautiful',
#   'ambience,',
#   'location',
#   'atmosphere',
#   'Resort',
#   'resort.',
#   'view',
#   'peaceful',
#   'ambiance',
#   'resort.',
#   'hotel',
#   'hotel',
#   'ambience',
#   'river',
#   'view',
#   'garden',
#   'Stay',
#   'park',
#   'spot',
#   'location,'],
#  'ambience,': ['nice', 'good', 'break'],
#  'food,': ['traceable.',
#   'nice',
#   'and',
#   'calmful',
#   'management',
#   'pleasant',
#   'its'],
#  'traceable.': ['Near'],
#  'Near': ['Munnar.'],
#  'spend': ['quality', 'quality', 'outdoors@'],
#  'ones': [':', 'Good'],
#  'resort': ['with',
#   'is',
#   'unlike',
#   ':',
#   'for',
#   'for',
#   'premises',
#   'had',
#   'staffs',
#   'to',
#   'is',
#   'but',
#   'were',
#   'to',
#   'in',
#   'with',
#   'is',
#   'to',
#   'located',
#   'for',
#   'located',
#   'I',
#   'was',
#   'is',
#   'owner',
#   'is',
#   'to',
#   'has',
#   'has',
#   'better.',
#   'website.',
#   '.',
#   'is',
#   'to',
#   'was',
#   'is',
#   'as',
#   'to',
#   'has',
#   'has',
#   'and',
#   'in',
#   'that',
#   '..'],
#  'surrounding': [':'],
#  'Most': ['rooms', 'of'],
#  'view.': ['Royal',
#   'But',
#   ':',
#   'Every',
#   'Rivulet',
#   'Really',
#   'Perfect',
#   'Food'],
#  'Royal': ['suite'],
#  'spacious': ['and',
#   'rooms,',
#   'room',
#   'and',
#   'and',
#   'and',
#   'with',
#   'and',
#   'room'],
#  'clean.': ['My',
#   'Location',
#   'The',
#   'Staff',
#   'Overall',
#   'Room',
#   'A',
#   'Food',
#   'Staff',
#   'Very',
#   'We'],
#  'My': ['room'],
#  'close': ['to', 'to', 'to'],
#  'had': ['great',
#   'a',
#   'a',
#   'a',
#   'gone',
#   'a',
#   'a',
#   'an',
#   'a',
#   'to',
#   'a',
#   'to',
#   'just',
#   'no',
#   'bottles',
#   '3',
#   'a',
#   'hired',
#   'a',
#   'to',
#   'to',
#   'to',
#   'booked'],
#  'But': ['was', 'that', 'this', 'it', 'the', 'overall', 'overall'],
#  'away': ['from',
# ...
#  'In': ['food', 'night', 'all', 'our'],
#  'option': ['for', 'for', 'from', 'was'],
#  'veg,': ['there'],
#  'more.': ['Good'],
#  'memorable': ['stay'],
#  'aspect,': ['situated'],
#  'situated': ['alongside', 'in'],
#  'alongside': ['a'],
#  'adequate.': ['Scenic'],
#  'Scenic': ['location'],
#  'offers': ['scenic'],
#  'scenic': ['view', 'villas', 'views,', 'beauty', 'beauty'],
#  'stayed': ['facing', 'there', 'in', 'in', 'with', 'for'],
#  'facing': ['River', 'along', 'the', 'apartment', 'which', 'cottages'],
#  'Side': ['bedroom'],
#  'bedroom': ['was', 'and'],
#  'offer': ['help', 'nature', 'you'],
#  'every': ['possible', 'room', 'penny,', 'penny.', 'thing', 'thing', 'penny.'],
#  'possible': ['way,'],
#  'way,': ['I'],
#  'love': ['to', 'to', 'with'],
#  'Road': ['to'],
#  'bad': ['condition,',
#   'stomach,',
#   'so',
#   'hospitality.',
#   'approach.',
#   'so',
#   'leading',
#   'its',
#   'part'],
#  'condition,': ['but'],
#  'lot.': ['Large', 'Best'],
#  'Large': ['rooms'],
#  'total': ['facilities'],
#  'Foof': ['quality'],
#  'requires': ['significant'],
#  'significant': ['improvement.'],
#  'improvement.': ['Awesome', 'The', 'The'],
#  'villas': [':', 'only,', 'adjacent', '.'],
#  'nights': ['in', 'stay.'],
#  'tamarind': ['villa.'],
#  'villa.': ['View', 'Rivulet'],
#  'just': ['heavenly',
#   'superb.',
#   'awesome.',
#   'okay',
#   'relaxed',
#   'reached',
#   'take',
#   'every',
#   'wish',
#   'it',
#   'wish',
#   'too'],
#  'heavenly': ['due'],
#  'due': ['to', 'to', 'to', 'to'],
#  'along': ['with', 'the', 'with'],
#  'mountains,': ['you'],
#  'wake': ['up'],
#  'bird': ['chirping', 'sounds,'],
#  'chirping': ['in', 'throughout'],
#  'morning,': ['while', 'have', 'which'],
#  'while': ['standing', 'driving.', 'the'],
#  'standing': ['in'],
#  'literally': ['feel'],
#  'fresh': ['air', 'and'],
#  'air': ['during'],
#  'inhaling': ['if'],
#  'coming': ['from'],
#  'City.': ['Very'],
#  'prompt': ['in'],
#  'Cycling': ['for'],
#  'If': ['you', 'you', 'you', 'you', 'any'],
#  'budget': ['then'],
#  'then': ['select', 'the', '(breakfast', 'were'],
#  'select': ['villas'],
#  'only,': ['food'],
#  'above': ['average'],
#  'considering': ['the'],
#  'amenities': ['and', 'which', 'are', 'are', 'and'],
#  'views,': ['you', 'great'],
#  'content': ['in'],
#  'overall.': ['Very', 'Its'],
#  'fabulous': ['experience'],
#  'Eco': ['friendly'],
#  'friendly': ['environment,',
#   'staffs.',
#   'staff.',
#   'and',
#   'staff',
#   'staff.',
#   'and',
#   "staff's,",
#   'and',
#   'staff'],
#  'environment,': ['nice'],
#  'staffs.': ['Neat'],
#  'Neat': ['and'],
#  'clean': ['room',
#   'and',
#   'and',
#   'rooms',
#   'amenities,',
#   'and',
#   'rooms',
#   'and',
#   'and',
#   'and'],
#  'well': ['as',
#   'maintained',
#   'maintained',
#   'trained.',
#   'maintained',
#   'and',
#   'maintained',
#   'kept,',
#   'kept.',
#   'furnished',
#   'maintained'],
#  'premises': ['and'],
#  'peaceful': ['location.',
#   'and',
#   'stay.',
#   'stay.',
#   'holidays.',
#   'holidays.',
#   'holiday',
#   'abode'],
#  "didn't": ['like', 'see', 'even'],
#  'road': ['towards', 'and', 'is'],
#  'towards': ['the', 'me,'],
#  'resort,': ['lots'],
#  'lots': ['of'],
#  'potholes': ['which'],
#  'upset': ['while', 'stomach'],
#  'driving.': ['Review'],
#  'Review': [':'],
#  'resort.': ['Worth',
#   'We',
#   'Good',
#   'There',
#   'Nice',
#   'Staff',
#   'We',
#   'Complimentary',
#   'Spacious',
#   'Average',
#   'Comfortable',
#   'It',
#   'Even',
#   'BIGGGGGG',
#   'Average',
#   'Good',
#   'Even',
#   'Good',
#   'Staff',
#   'Awesome!',
#   'Good',
#   'Good'],
#  'Worth': ['for', 'every', 'staying'],
#  'money.': ['Like', 'Good', 'The', 'This', 'Not', 'Again,', 'Food'],
#  'Like': ['to', 'we'],
#  'maintained': ['cottages',
#   'cottages,',
#   'and',
#   'near',
#   'and',
#   'along',
#   'absolutely',
#   'and'],
#  'cottages': [':', 'are', 'were', 'were', 'were', 'and'],
#  'Would': ['recommend', 'definitely', 'recommend', 'suggest', 'definitely'],
#  'families.': ['Amazing'],
#  'cottages,': ['though'],
#  'though': ['expensive,', 'they', 'it', 'I', 'its', 'variety'],
#  'expensive,': ['food'],
#  'Staffs': ['were'],
#  'too.': ['Not', 'Ayurvedic', 'Food', 'Unbeatable'],
#  'Not': ['to', 'many', 'worth', 'recommended', 'a', 'good'],
#  'repeated': [':'],
#  'Lack': ['of'],
#  'major': ['communication'],
#  'communication': ['gap'],
#  'gap': ['between'],
#  'between': ['the', '8:00-9:30', 'such'],
#  'management': ['and', 'and', 'should'],
#  'Restaurant': ['is', 'serves'],
#  'expensive': ['and', 'but'],
#  "don't": ['have', 'go', 'enjoy', 'prefer'],
#  'system': ['and'],
#  'minimum.': ['Room'],
#  'Room': ['was', 'was', 'service', 'service', 'is', 'service', 'Service'],
#  'cut': ['off'],
#  'off': ['the', 'was', 'from', 'from', 'from'],
#  'minimum': ['options'],
#  'fantastic.': ['Sounds', 'Great'],
#  'Sounds': ['of'],
#  'water': ['was', 'flowing', 'stream.', 'flow', 'flow'],
#  'trained.': ['It'],
#  'Shower': ['partition'],
#  'partition': ['would'],
#  'helped.': ['One'],
#  'rivulet': [':',
#   'from',
#   'flowing',
#   'flowing',
#   'flowing',
#   'singing',
#   'resort.',
#   'we'],
#  'Suite': ['rooms'],
#  'superb.': ['Have'],
#  'Have': ['coffee', 'a'],
#  'coffee': ['with'],
#  'sleep': ['with'],
#  'sound': ['of', 'of', 'and', 'from'],
#  'water.': ['Dinner'],
#  'Dinner': ['was'],
#  'needs': ['improvement',
#   'to',
#   'attention',
#   'improvement.',
#   'training',
#   'improvement.',
#   'to',
#   'improvement'],
#  'improvement': ['with', 'on', '.'],
#  'Just': ['want', 'the', 'have'],
#  'say': ['it', 'it', 'but', 'but'],
#  'property.': ['Everything', 'Staff', 'Nice', 'However,'],
#  'fine': ['we', 'but'],
#  'liked': ['the', 'escaping'],
#  'Recommend': ['to'],
#  'town': ['but', 'which', 'center.', 'and', 'and'],
#  'get.': ['The'],
#  'flowing': ['river',
#   'river',
#   'was',
#   'and',
#   'was',
#   'right',
#   'by.',
#   'by',
#   'on',
#   'through',
#   'by'],
#  'Really': ['nice', 'enjoyed', 'awesome', 'awesome'],
#  'adjacent': ['to'],
#  'makes': ['this', 'your'],
#  'destination': ['a'],
#  'try.': ['Amazing'],
#  'river/waterfall': ['view'],
#  'Only': ['the', 'negative', 'one', 'thing', 'issue', 'bad', 'thing'],
#  'prices': ['are'],
#  'otherwise': ['everything', 'the'],
#  'perfect.': ['Munnar', 'Good', 'I', 'Rooms'],
#  'superb': ['service.', 'spread', 'including'],
#  'may': ['look', 'be', 'not'],
#  'look': ['long', 'spic', 'fresh', 'was'],
#  'long': ['from', 'way'],
#  "it's": ['worth', 'a'],
#  'worth': ['to',
#   'the',
#   'it',
#   'the',
#   'paying',
#   'the',
#   'spending',
#   'for',
#   'a',
#   'every',
#   'paying',
#   'staying'],
#  'long.': ['amenities'],
#  'seen.': ['Nice'],
#  'outside.': ['Excellent'],
#  'Pallivasal': ['Hydel'],
#  'Hydel': ['Project'],
#  'Project': ['of'],
#  'KSEB.': ['Excellent'],
#  'easy': ['accessible'],
#  'accessible': ['distance'],
#  'distance': ['and', 'from'],
#  'really': ['excellent.',
#   'loved',
#   'nice.',
#   'great',
#   'memorable,',
#   'satisfying.',
#   'clean',
#   'worth',
#   'beautiful',
#   'good',
#   'fantastic.',
#   'helpful.',
#   'loved',
#   'a',
#   'enjoyed',
#   'worth',
#   'made',
#   'becomes'],
#  'Cut': ['away'],
#  'bustle,': ['we'],
#  'relaxed': ['2', 'stay.', 'atmosphere.', 'your'],
#  '2': ['day', 'night', 'days', 'nights', 'day', 'hours'],
#  'day': ['stay.', 'stay.', 'staying', 'was', 'trips.', 'only'],
#  'Could': ['hear', 'be', 'not'],
#  'throughout': ['and'],
#  'taking': ['a'],
#  'stroll': ['around'],
#  'efficient': ['and'],
#  'helpful.': ['Food', 'Would', 'A', 'The', 'They'],
#  'managed': ['to', 'to', 'by'],
#  'vegetarian': ['options.', 'food', 'and'],
#  'options.': ['We'],
#  'Ayurvedic': ['spa', 'Spa'],
#  'tried': ['our', 'hard'],
#  'hand': ['at'],
#  'archery': ['with', 'were', 'while', 'very'],
#  'Mr.': ['Shihab.', 'Shahib', 'Shihab', 'Ajay'],
#  'Shihab.': ['He'],
#  'He': ['was'],
#  'patient': ['and'],
#  'encouraging': ['and'],
#  'actually': ['managed', 'very'],
#  'shots.': ['Would'],
#  'future.': ['Complete'],
#  'Complete': ['awesome'],
#  'Location,': ['food,'],
#  'gone': ['there'],
#  'celebrate': ['our'],
#  "dad's": ['birthday.'],
#  'birthday.': ['The'],
#  'Every': ['room', 'thing'],
#  'continuous': ['sound'],
#  'soothing.': ['The'],
#  'OK.': ['Rooms'],
#  'bathroom': ['were'],
#  'staffs': ['were'],
#  'anyone': ['visiting'],
#  'visiting': ['Munnar.'],
#  'turn': ['off'],
#  '15-18': ['km'],
#  'km': ['An', 'away'],
#  'An': ['excellent', 'experience', 'excellent', 'ideal'],
#  'whole': ['family', 'experience'],
#  '3': ['days', 'royal', 'days', 'day'],
#  'cottage,': ['sceneries', 'forest'],
#  'sceneries': [':'],
#  'prime': ['location,'],
#  'views': ['from', 'and', 'but', 'on'],
#  'cottage.': ['Nice'],
#  'reduced.': ['Overall'],
#  'one': ['of',
#   'fantastic',
#   'problem',
#   'day',
#   'night.',
#   'would',
#   'day',
#   'day.'],
#  'experienced.': ['You'],
#  'see': ['the', 'this', 'the', 'were'],
#  'misty': ['mountains'],
#  'mountains': ['lying', 'and', 'and'],
#  'lying': ['in'],
#  'bed': ['which'],
#  'sheer': ['bliss.'],
#  'bliss.': ['The'],
#  'friendly,': ['helpful', 'food'],
#  'smiling.': ['The'],
#  'pictures': ['on', '..'],
#  'MakeMyTrip': ['and'],
#  'their': ['website', 'kitchen', 'resort.', 'advantage.', 'needs.'],
#  'website': ['definitely'],
#  'do': ['not', 'the', 'better', 'think', 'not', 'not', 'not', 'nothing.'],
#  'justice': ['to'],
#  'real': ['beauty'],
#  'beauty': ['of', 'around', 'and'],
#  'place.': ['The', 'The', 'We', 'You'],
#  'disappointment': ['was'],
#  'Far': ['away'],
#  'climate': ['is', 'is'],
#  'totally': ['different'],
#  'different': ['from', 'experience', 'varieties,'],
#  'average.': ['Activities', 'Breakfast'],
#  'Activities': ['are', 'like'],
#  'less.': ['Trekking'],
#  'Trekking': ['was'],
#  'Over': ['priced.'],
#  'part.': ['Food'],
#  'last': ['night'],
#  'did': ['not'],
#  'served': ['food', 'was'],
#  'properly,': ['as'],
#  'kitchen': ['closed'],
#  'closed': ['at', 'but'],
#  '9': ['PM.'],
#  'PM.': ['Poor'],
#  'Poor': ['room', 'Stay', 'Stay', 'Stay', 'Stay', 'Stay'],
#  'late': ['in'],
#  'serving': ['food.'],
#  'remember': [':'],
#  'breathtakingly': ['beautiful,'],
#  'beautiful,': ['the', 'rooms', 'dinner'],
#  'better,': ['but', ':'],
#  'cuckoo': ['sounds'],
#  'sounds': ['are'],
#  'noisy': ['spa', 'area.'],
#  'rooms.': ['Good', 'Good', 'Nice', 'Not'],
#  'Wrong': ['direction'],
#  'direction': ['was'],
#  'provided': ['by', 'by', 'by', 'all'],
#  'employee.': ['Hence'],
#  'Hence': ['we'],
#  'lost': ['our'],
#  'way': ['in', 'from', 'in', 'in'],
#  'night.': ['Serene', 'Location'],
#  'Serene': ['location'],
#  'traffic': ['you', 'crossings', 'but'],
#  'crowd.': ['The'],
#  'bank': ['of'],
#  'side': ['of', ':', 'down'],
#  'full': ['of', 'satisfaction'],
#  'green.': ['That'],
#  'That': ['view'],
#  'take': ['your', 'a', 'a', 'care'],
#  'breath.': ['The'],
#  'both': ['options,'],
#  'options,': ['buffet'],
#  'la': ['carte.'],
#  'carte.': ['Overall'],
#  'satisfying': ['stay.'],
#  'value': ['for', 'for', 'for', 'for', 'for', 'for', 'for', 'of', 'for'],
#  'o': ['stay'],
#  'Rivulet,': ['nice'],
#  'Mr': ['Shijo'],
#  'Shijo': ['from'],
#  'front': ['office', 'of'],
#  'office': ['gave'],
#  'valuable': ['suggestions'],
#  'suggestions': ['to'],
#  'memorable,': ['warm'],
#  'welcome': ['and', 'was'],
#  '.': [':',
#   'Overall,',
#   'Very',
#   'Rooms',
#   '.',
#   'For',
#   '.',
#   'Away',
#   'Particularly',
#   'The',
#   'Although',
#   ':',
#   'Excellent'],
#  'cold': ['(hot'],
#  '(hot': ['days'],
#  'April': ['9-13)'],
#  '9-13)': ['as'],
#  '12-13': ['kms'],
#  'below': ['Munnar'],
#  'restricted': ['the'],
#  'outdoors@': ['the'],
#  'A/cs': ['in'],
#  'offset': ['the'],
#  'warmer': ['mornings.'],
#  'mornings.': ['Ambience'],
#  'Ambience': ['and', 'was'],
#  'park,': ['badminton'],
#  'badminton': ['courts,', 'court.'],
#  'courts,': ['trekking'],
#  'trekking': ['paths', 'option'],
#  'paths': ['and'],
#  'relaxing.': ['It'],
#  '&': ['peaceful', 'enjoy', 'less', 'soul', 'friendly', 'food'],
#  'park': ['and', 'for'],
#  'trek': ['through', 'into', 'worth'],
#  'through': ['the', 'the'],
#  'quite': ['good.',
#   'a',
#   'challenging',
#   'good.',
#   'good.',
#   'peaceful',
#   'workouts',
#   'warm.',
#   'good.',
#   'bad.'],
#  'On': ['the'],
#  'flip': ['side,'],
#  'side,': ['the'],
#  'inaccessible': ['and'],
#  'polluted': ['too.'],
#  'Spa': ['was'],
#  'money': ['spend,', 'The', ':', 'you', 'monetary'],
#  'spend,': ['especially'],
#  'especially': ['for', 'Mr.', 'in', 'river,'],
#  'used': ['to', 'or'],
#  'treatments': ['and'],
#  'locally': ['which'],
#  'cheaper': ['too.'],
#  'decent': ['but', 'property.', 'parking'],
#  'pretty': ['set', 'good'],
#  'menu': ['for', 'is', 'Good', 'card', 'could'],
#  'breakfast.': ['Variety', 'The', 'The'],
#  'even': ['more', 'react', 'though', 'though', 'the', 'more', 'more'],
#  'local': ['cuisine', 'delicacies.', 'taxi'],
#  'cuisine': ['would'],
#  'preferable.': ['.'],
#  'Overall,': ['this', 'we'],
#  'Unbeatable': ['location', 'location'],
#  'co-operative': ['staff!', 'staff', 'beautiful', 'and'],
#  'staff!': [':'],
#  '!.': ['The', 'Only'],
#  'pics': ['are', 'and'],
#  'true': ['to'],
#  'actual': ['experience', '/'],
#  'beauty.': ['Lot'],
#  'Lot': ['of'],
#  'space': ['within'],
#  'within': ['the', '5'],
#  'walk': ['along', 'up', 'is', 'between', 'in'],
#  '(river': ['flow'],
#  'flow': ['subjected', 'in', 'primarily'],
#  'subjected': ['to'],
#  'season': ['and', 'was'],
#  'dam': ['above),', 'flowing'],
#  'above),': ['small'],
#  'tea': ['gardens,',
#   'there',
#   'plantations',
#   'gardens.',
#   'gardens,',
#   'materials',
#   'pepper',
#   'garden',
#   'gardens,'],
#  'gardens,': ['small', 'pepper', 'pepper'],
#  'bridge,': ['seating'],
#  'seating': ['next'],
#  '(bon-fire': ['place),'],
#  'place),': ['view'],
#  'rooms-': ['all'],
#  'fascinating.': ['You'],
#  'Moselberg': ['resort'],
#  'change,': ['if'],
#  'further': ['till'],
#  'till': ['the', 'then', 'the'],
#  'temple': ['then'],
#  'satisfying.': ['Must'],
#  'mention': ['Mr.', 'the'],
#  'Shahib': ['who'],
#  'guide': ['for'],
#  '8.': ['30am'],
#  '30am': ['trek'],
#  'into': ['the'],
#  'huge': ['plantations', 'area', 'and', 'area'],
#  'plantations': ['behind', 'near'],
#  'behind': ['the', 'the'],
#  'resort-': ['his', 'with'],
#  'his': ['knowledge', 'zeal', 'way'],
#  'knowledge': ['about'],
#  'fauna': ['and'],
#  'zeal': ['to'],
#  'engage': ['the'],
#  'audience': ['made'],
#  'whatever': ['you'],
#  'ask-': ['adhoc'],
#  'adhoc': ['request'],
#  'request': ['for'],
#  'bon-fire,': ['archery.'],
#  'archery.': ['We'],
#  'requested': ['for'],
#  'ripe': ['papaya'],
#  'papaya': ['hanging'],
#  'hanging': ['from'],
#  'plants': ['in'],
#  'no': ['hiccups,',
#   'water',
#   'board',
#   'such',
#   'discount.',
#   'words',
#   'facilities',
#   'doubt',
#   'one'],
#  'hiccups,': ['it'],
#  'plugged,': ['wrapped'],
#  'wrapped': ['and'],
#  'given': [':)', 'room', 'for'],
#  ':)': ['delicious'],
#  'organic': ['stuff'],
#  'stuff': ['and'],
#  'show': ['of'],
#  'kindness': ['!.'],
#  'negative': ['I'],
#  'felt': ['and'],
#  'experienced': ['was', 'was'],
#  'quality.': ['Taste'],
#  'Taste': ['was'],
#  'stale.': ['But'],
#  "shouldn't": ['be'],
#  'deterrent': ['as'],
#  'specific': ['review'],
#  'review': ['by'],
#  'others.': ['Almost'],
#  'Almost': ['all'],
#  'faced': ['some'],
#  'extent': ['of'],
#  'stomach,': ['so'],
#  'eat': ['out'],
#  'out': ['for', 'of', 'of', 'of', 'of', 'early,', 'of'],
#  'one-two': ['meals.'],
#  'meals.': ['There'],
#  'fantastic': ['veg', 'ambience,', 'and', ':'],
#  'veg': ['restaurant', 'sandwich,'],
#  'downtown': ['Munnar,'],
#  'Munnar,': ['everyone', 'need'],
#  'everyone': ['would'],
#  'know.': ['Couple'],
#  'Couple': ['of'],
#  'restaurants': ['in', 'near', 'nearby'],
#  'market': ['near'],
#  'Friendly': ['staff'],
#  'variety.': ['Loved'],
#  'orchards': ['were'],
#  'Decent': ['place', 'value', 'value'],
#  'okay': ['kind', 'A', ':', 'but'],
#  'kind': [':', 'and'],
#  'match': ['to', 'our'],
#  'expectation': ['and', 'as'],
#  'stratifying.': ['Food'],
#  'right': ['from', 'in', 'beside', 'place', 'now.'],
#  'room!': [':'],
#  'THis': ['is'],
#  'Ideal': ['for'],
#  'live': ['a', 'in'],
#  'center.': ['We'],
#  'advertised': ['in'],
#  'photos.': ['The'],
#  'add': ['more'],
#  'delicacies.': ['Not'],
#  'meant': ['for'],
#  'isolated': ['and'],
#  'atmosphere.': ['Good'],
#  'Spacious,': ['neat,'],
#  'neat,': ['clean'],
#  'spice': ['plantation', 'plantation'],
#  'plantation': ['walk,', 'walk.', 'owned', 'and', 'which', 'and', 'which'],
#  'Archery,': ['Bamboo'],
#  'Bamboo': ['rafting,', 'boat,'],
#  'rafting,': ['Games'],
#  'Games': ['etc', 'room'],
#  'etc': ['are', 'which'],
#  'Shihab': ['who'],
#  'teaches': ['archery'],
#  'guides': ['spice'],
#  'walk.': ['Just', 'Definitely', 'Rooms'],
#  'area,': ['so', 'and', 'cleanliness,', 'with'],
#  'need': ['your', 'proper', 'to'],
#  'own': ['vehicle.', 'plantation', 'tea', 'plantation'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(rr_dict)
# Out:
# 'Behind the city, nothing extraordinary. Has nice guesthouse with a great place to remember :.'
